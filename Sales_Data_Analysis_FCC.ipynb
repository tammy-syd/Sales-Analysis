# %% [markdown]
# # Sale data analysis ( FCC Keith Galli)

# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1: Merge 12 months of sales data to 1 files

# %%
df=pd.read_csv("Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/Sales_April_2019.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# Read all sales data files

files=[file for file in os.listdir('Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data')]

print(files)
# Out:
# ['Sales_April_2019.csv', 'Sales_August_2019.csv', 'Sales_December_2019.csv', 'Sales_February_2019.csv', 'Sales_January_2019.csv', 'Sales_July_2019.csv', 'Sales_June_2019.csv', 'Sales_March_2019.csv', 'Sales_May_2019.csv', 'Sales_November_2019.csv', 'Sales_October_2019.csv', 'Sales_September_2019.csv']

# %%
# Merge everything into 1 Data Frame

all_months=pd.DataFrame() # Empty df

dff=pd.DataFrame()

for file in files:
    dff=pd.read_csv("Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/"+file)
    all_months=pd.concat([all_months,dff])
all_months
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
# Merge 12 months data to 1 csv file
all_months.to_csv('Pandas-Data-Science-Tasks-master/SalesAnalysis/all_months_data.csv',index=False)

# %%
# Updated DataFrame

all_df=pd.read_csv("Pandas-Data-Science-Tasks-master/SalesAnalysis/all_months_data.csv")
all_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# # Data cleaning and Modification

# %% [markdown]
# ## Delete null values

# %%
# Check and delete null values

all_df.isnull().any()

# Drop rows with NaN

nan_df=all_df[all_df.isna().any(axis=1)]
nan_df
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
all_df=all_df.dropna(how='all')
all_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Add month column
# ### Use to answer Q1

# %%
all_df['Month']= all_df['Order Date'].str[0:2]

# Convert Month from str to int

#all_df['Month']= all_df['Month'].astype('int32')

# Find and delete 'Or' to prevent error
all_df=all_df[all_df['Order Date'].str[0:2] != 'Or']

all_df['Month']= all_df['Month'].astype('int32')


all_df
# Out:
# <ipython-input-165-6820e632bf19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Month']= all_df['Order Date'].str[0:2]
# <ipython-input-165-6820e632bf19>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Month']= all_df['Month'].astype('int32')
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# ...

# %% [markdown]
# ### Convert columns from str to int

# %%
# New way
all_df['Quantity Ordered']= pd.to_numeric(all_df['Quantity Ordered'])

all_df['Price Each']= all_df['Price Each'].astype('float')

all_df
# Out:
# <ipython-input-166-5bfb7d4225c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Quantity Ordered']= pd.to_numeric(all_df['Quantity Ordered'])
# <ipython-input-166-5bfb7d4225c8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Price Each']= all_df['Price Each'].astype('float')
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# ...

# %% [markdown]
# ### Add sales column = Quantity Ordered * Price Each

# %%
all_df['Sales'] = all_df['Price Each'] * all_df['Quantity Ordered']
all_df
# Out:
# <ipython-input-167-b710cb4b27e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Sales'] = all_df['Price Each'] * all_df['Quantity Ordered']
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %% [markdown]
# # Q1: Best month for sales ? How much was earned that month ?

# %%
money_df=all_df.groupby(all_df['Month']).sum()
money_df
# Out:
#        Quantity Ordered    Price Each   Month         Sales
# Month
# 1                 10903  1.811768e+06    9709  1.822257e+06
# 2                 13449  2.188885e+06   23950  2.202022e+06
# 3                 17005  2.791208e+06   45459  2.807100e+06
# 4                 20558  3.367671e+06   73116  3.390670e+06
# 5                 18667  3.135125e+06   82830  3.152607e+06
# 6                 15253  2.562026e+06   81324  2.577802e+06
# 7                 16072  2.632540e+06  100051  2.647776e+06
# 8                 13448  2.230345e+06   95688  2.244468e+06
# 9                 13109  2.084992e+06  104589  2.097560e+06
# 10                22703  3.715555e+06  202820  3.736727e+06
# 11                19798  3.180601e+06  193303  3.199603e+06
# 12                28114  4.588415e+06  299808  4.613443e+06

# %%
months = range(1,13)
plt.bar(months,money_df['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD (million)')
plt.xlabel('Month')
plt.show()

# %% [markdown]
# # Q2:What city sold the most product?

# %% [markdown]
# ### Add a city column

# %%
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]



#all_df['City'] = all_df['Purchase Address'].apply(lambda x: x.split(',')[1])

all_df['City'] = all_df['Purchase Address'].apply(lambda x : f"{get_city(x)}  ({get_state(x)})")


all_df
# Out:
# <ipython-input-170-0be49e1e1adc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['City'] = all_df['Purchase Address'].apply(lambda x : f"{get_city(x)}  ({get_state(x)})")
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
city_df=all_df.groupby(all_df['City']).sum()
city_df
# Out:
#                       Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta  (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin  (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston  (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas  (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles  (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City  (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland  (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland  (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco  (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle  (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
# Get unique value in a df
# City order messed up => Chart wrong

#cities=all_df['City'].unique()

cities=[city for city , df in all_df.groupby('City')]

plt.bar(cities,city_df['Sales'],color='green')
plt.xticks(cities,rotation='vertical',color='black')
plt.ylabel('Sales in USD (million)')
plt.xlabel('City')
plt.show()

# %% [markdown]
# # Q3: What time should we display advertisemens to maximize the likelihood of customer’s buying product?

# %% [markdown]
# ### Change Order Date from str to datetime

# %%
all_df['Order Date'] = pd.to_datetime(all_df['Order Date'])
all_df
# Out:
# <ipython-input-173-754d605cbb85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Order Date'] = pd.to_datetime(all_df['Order Date'])
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %% [markdown]
# ### Add Hour and Minute column

# %%
all_df['Hour'] = all_df['Order Date'].dt.hour
all_df['Minute'] = all_df['Order Date'].dt.minute


all_df.head()
# Out:
# <ipython-input-174-ab3c2703dbea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Hour'] = all_df['Order Date'].dt.hour
# <ipython-input-174-ab3c2703dbea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_df['Minute'] = all_df['Order Date'].dt.minute
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# ...

# %%
hours=[hour for hour , df in all_df.groupby('Hour')]

plt.plot(hours,all_df.groupby('Hour').count())


plt.xticks(hours , size=8 )

plt.grid()

plt.ylabel('Quantity Ordered')
plt.xlabel('Hour')
plt.show()


# Recommendation: Display ads at around 11:00 and 19:00

# %% [markdown]
# # Q4: What products are most often sold together?

# %% [markdown]
# ## Plot twist: Products sold together have the same ID

# %% [markdown]
# ### Create new df with duplicated Order IDs

# %%
new_df = all_df[all_df['Order ID'].duplicated(keep=False)]
new_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  Month  \
# ...

# %% [markdown]
# ### Add new column: Grouped
# ### Join products with same ID

# %%
new_df['Grouped'] = new_df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
new_df
# Out:
# <ipython-input-177-5b4121a4287b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Grouped'] = new_df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# ...

# %%
# Get rid of duplicated in Grouped column

new_df = new_df[['Order ID','Grouped']].drop_duplicates()

new_df
# Out:
#        Order ID                                            Grouped
# 3        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32       176586                AAA Batteries (4-pack),Google Phone
# 119      176672      Lightning Charging Cable,USB-C Charging Cable
# ...         ...                                                ...
# 186781   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 186783   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 186791   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in new_df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
    
# Most common combo
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# # Q5: What product sold the most? Why do you think it sold the most?

# %%
product_group_total = all_df.groupby('Product').sum()['Quantity Ordered']

product_group_total
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
products = [product for product, df in all_df.groupby('Product')]

plt.bar(products,product_group_total,color='green')

plt.xticks(products,rotation='vertical',color='black')

plt.ylabel('Quantity Ordered')

plt.xlabel('Product')

plt.show()

# %%
# Explain why AAA Batteries and AA Batteries sold the most

price = all_df.groupby('Product').mean()['Price Each']

price
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %% [markdown]
# ### Add a second y-axis to the product chart above

# %%
fig,axis1 = plt.subplots()

axis1.bar(products,product_group_total,color='green')

axis2 = axis1.twinx()
axis2.plot(products,price,color='blue')

axis1.set_xlabel('Product')
axis1.set_ylabel('Number of Orders')
axis2.set_ylabel ('Price')

# Fix the name
axis1.set_xticklabels(products,rotation='vertical' )

plt.show()
